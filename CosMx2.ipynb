# %% [markdown]
# https://nanostring.com/products/cosmx-spatial-molecular-imager/ffpe-dataset/
# Lung5_Rep1

# %% [markdown]
# https://nanostring-public-share.s3.us-west-2.amazonaws.com/SMI-Compressed/SMI-ReadMe.html

# %%
cd /content/drive/MyDrive/datasets/cosmx-smi-ffpe
# Out:
# /content/drive/MyDrive/datasets/cosmx-smi-ffpe

# %%
import pandas as pd

# %%
df=pd.read_parquet("data.parquet")

# %%
pd.unique(df['target']).size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ae169fb8ab1d> in <module>()
# ----> 1 pd.unique(df['target']).size()
#
# TypeError: 'int' object is not callable

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3cac5fec75c4> in <module>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 train, test = train_test_split(df, test_size=0.2)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2443     return list(
#    2444         chain.from_iterable(
# -> 2445             (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2446         )
#    2447     )
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in <genexpr>(.0)
#    2443     return list(
#    2444         chain.from_iterable(
# -> 2445             (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2446         )
#    2447     )
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/__init__.py in _safe_indexing(X, indices, axis)
#     374
#     375     if hasattr(X, "iloc"):
# --> 376         return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     377     elif hasattr(X, "shape"):
#     378         return _array_indexing(X, indices, indices_dtype, axis=axis)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/__init__.py in _pandas_indexing(X, key, key_dtype, axis)
#     216         # using take() instead of iloc[] ensures the return value is a "proper"
#     217         # copy that will not raise SettingWithCopyWarning
# --> 218         return X.take(key, axis=axis)
#     219     else:
#     220         # check whether we should index with loc or iloc
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3614
#    3615         new_data = self._mgr.take(
# -> 3616             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3617         )
#    3618         return self._constructor(new_data).__finalize__(self, method="take")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify)
#     868             axis=axis,
#     869             allow_dups=True,
# --> 870             consolidate=False,
#     871         )
#     872
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     686                     ),
#     687                 )
# --> 688                 for blk in self.blocks
#     689             ]
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     686                     ),
#     687                 )
# --> 688                 for blk in self.blocks
#     689             ]
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1143
#    1144         new_values = algos.take_nd(
# -> 1145             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1146         )
#    1147
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/array_algos/take.py in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     106
#     107     arr = np.asarray(arr)
# --> 108     return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     109
#     110
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/array_algos/take.py in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     152         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     153     )
# --> 154     func(arr, indexer, out, fill_value)
#     155
#     156     if flip_order:
#
# KeyboardInterrupt:

# %%
train.to_parquet("/content/drive/MyDrive/datasets/cosmx-smi-ffpe/train.parquet")
test.to_parquet("/content/drive/MyDrive/datasets/cosmx-smi-ffpe/test.parquet")

# %% [markdown]
# Build a feedforward network that predicts `target` from the dataset using the remaining attributes
